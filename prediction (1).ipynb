# %%
import tensorflow
from tensorflow.keras.models import load_model
import pickle
import pandas as pd

model=load_model('model.h5')

with open('scaler.pkl','rb') as file:
    scaler=pickle.load(file)

with open('one_hot_encoder.pkl','rb') as file:
    one_enc=pickle.load(file)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
input_data={
    'CreditScore':64567,
    'Geography':'France',
    'Gender':'Male',
    'Age':40,
    'Tenure':3,
    'Balance':6456878645,
    'NumOfProducts':2,
    'HasCrCard':1,
    'IsActiveMember':0,
    'EstimatedSalary':50000
}

# %%
input_df=pd.DataFrame([input_data])
input_df
# Out:
#    CreditScore Geography Gender  Age  Tenure     Balance  NumOfProducts  \
# 0        64567    France   Male   40       3  6456878645              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               0            50000

# %%
cat_sparsed=one_enc.transform(input_df[['Geography','Gender']])

# %%
cat_encoded=pd.DataFrame(cat_sparsed,columns=one_enc.get_feature_names_out())

# %%
cat_encoded
# Out:
#    Geography_France  Geography_Germany  Geography_Spain  Gender_Female  \
# 0               1.0                0.0              0.0            0.0
#
#    Gender_Male
# 0          1.0

# %%
input_df=pd.concat([input_df,cat_encoded],axis=1)

# %%
input_df
# Out:
#    CreditScore Geography Gender  Age  Tenure     Balance  NumOfProducts  \
# 0        64567    France   Male   40       3  6456878645              2
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Geography_France  \
# 0          1               0            50000               1.0
#
#    Geography_Germany  Geography_Spain  Gender_Female  Gender_Male
# 0                0.0              0.0            0.0          1.0

# %%
input_df=input_df.drop(['Geography','Gender'],axis=1)

# %%
input_df
# Out:
#    CreditScore  Age  Tenure     Balance  NumOfProducts  HasCrCard  \
# 0        64567   40       3  6456878645              2          1
#
#    IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# 0               0            50000               1.0                0.0
#
#    Geography_Spain  Gender_Female  Gender_Male
# 0              0.0            0.0          1.0

# %%
input_scaled=scaler.transform(input_df)

input_scaled
# Out:
# array([[ 6.54491595e+02,  9.47717186e-02, -6.98445493e-01,
#          1.03942976e+05,  8.05105366e-01,  6.33673177e-01,
#         -1.05026160e+00, -8.48050468e-01,  9.80196059e-01,
#         -5.75810666e-01, -5.63491843e-01, -9.09111664e-01,
#          9.09111664e-01]])

# %%
pred=model.predict(input_df)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step

# %%
pred
# Out:
# array([[1.]], dtype=float32)

# %%
prediction_probablity=pred[0][0]

if prediction_probablity>0.5:
    print("Churned")
else:
    print("Not Churned")
# Out:
# Churned

# %%
one_enc.categories_
# Out:
# [array(['France', 'Germany', 'Spain'], dtype=object),
#  array(['Female', 'Male'], dtype=object)]
